# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(42)

n_points = 10
a = np.array([[i, 0] for i in range(n_points)])
b = np.array([[i, 1] for i in range(n_points)])
c = np.array([[i, 1.6] for i in range(n_points)])

plt.figure(figsize=(6, 3))
plt.scatter(a[:, 0], a[:, 1], label='supp($p(x)$)')
plt.scatter(b[:, 0], b[:, 1], label='supp($q(x)$)')
plt.scatter(c[:, 0], c[:, 1], label='supp($q(x)$)')
plt.legend();

# %%
import torch
from layers import SinkhornDistance

x = torch.tensor(a, dtype=torch.float)
y = torch.tensor(b, dtype=torch.float)
z = torch.tensor(c, dtype=torch.float)

sinkhorn = SinkhornDistance(eps=0.1, max_iter=100)
dist, P, C = sinkhorn(x, y,z)
print("Sinkhorn distance: {:.3f}".format(dist.item()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       6 z = torch.tensor(c, dtype=torch.float)
#       8 sinkhorn = SinkhornDistance(eps=0.1, max_iter=100)
# ----> 9 dist, P, C = sinkhorn(x, y,z)
#      10 print("Sinkhorn distance: {:.3f}".format(dist.item()))
#
# File ~/anaconda3/envs/delta/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: forward() takes 3 positional arguments but 4 were given

# %%
plt.imshow(C)
plt.title('Distance matrix')
plt.colorbar();
